# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI', '^FTSE']
ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='2010-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                   ^GSPC        ^IXIC       ^GDAXI        ^FTSE
# Date
# 2010-01-04  1132.989990  2308.419922  6048.299805  5500.299805
# 2010-01-05  1136.520020  2308.709961  6031.859863  5522.500000
# 2010-01-06  1137.140015  2301.090088  6034.330078  5530.000000
# 2010-01-07  1141.689941  2300.050049  6019.359863  5526.700195
# 2010-01-08  1144.979980  2317.169922  6037.609863  5534.200195

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI        ^FTSE
# Date
# 2017-11-09  2584.620117  6750.049805  13182.559570  7484.100098
# 2017-11-10  2582.300049  6750.939941  13127.469727  7433.000000
# 2017-11-13  2584.840088  6757.600098  13074.419922  7415.200195
# 2017-11-14  2578.870117  6737.870117  13033.480469  7414.399902
# 2017-11-15  2568.830078  6711.811523  12976.370117  7372.609863

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15,6))
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^FTSE
# Date
# 2017-11-09 -0.003762 -0.005755 -0.014935 -0.006056
# 2017-11-10 -0.000898  0.000132 -0.004179 -0.006828
# 2017-11-13  0.000984  0.000987 -0.004041 -0.002395
# 2017-11-14 -0.002310 -0.002920 -0.003131 -0.000108
# 2017-11-15 -0.003893 -0.003867 -0.004382 -0.005636

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.114174
# ^IXIC     0.148624
# ^GDAXI    0.121441
# ^FTSE     0.048462
# dtype: float64

# %%
tickers = ['PWR', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2010-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                   PWR        ^GSPC          ^DJI
# Date
# 2017-11-09  35.509998  2584.620117  23461.939453
# 2017-11-10  35.840000  2582.300049  23422.210938
# 2017-11-13  36.720001  2584.840088  23439.699219
# 2017-11-14  35.750000  2578.870117  23409.470703
# 2017-11-15  35.509998  2567.060059  23284.849609

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15, 6))
plt.show()

# %%
import math

math.sqrt(.0033)
# Out:
# 0.05744562646538029

# %%
print(str((math.sqrt(.16))*100) + ' %')
# Out:
# 40.0 %
