# %%
import numpy as np
import pandas as pd

# %%
ser = pd.Series(np.random.random(5), name = "Column 01")

# %%
ser
# Out:
# 0    0.067151
# 1    0.517802
# 2    0.607641
# 3    0.420367
# 4    0.204108
# Name: Column 01, dtype: float64

# %%
ser[2]
# Out:
# 0.60764099249222525

# %%
from pandas_datareader import data as wb

# %%
PWR = wb.DataReader('PWR', data_source='yahoo', start='2010-1-1')

# %%
PWR
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2010-01-04  21.120001  21.280001  21.000000  21.240000  21.240000  2460200
# 2010-01-05  21.320000  21.500000  21.100000  21.330000  21.330000  2156000
# 2010-01-06  21.360001  22.100000  21.260000  21.940001  21.940001  2901900
# 2010-01-07  21.980000  22.350000  21.860001  22.270000  22.270000  1940800
# 2010-01-08  22.129999  22.219999  21.700001  21.860001  21.860001  2612400
# 2010-01-11  21.920000  21.959999  20.650000  20.980000  20.980000  6053300
# 2010-01-12  20.850000  20.930000  20.430000  20.590000  20.590000  3404200
# 2010-01-13  20.600000  20.700001  20.040001  20.629999  20.629999  3291000
# 2010-01-14  20.209999  20.400000  19.340000  19.440001  19.440001  5720000
# 2010-01-15  19.520000  19.570000  19.040001  19.059999  19.059999  5393000
# 2010-01-19  18.500000  18.650000  17.959999  18.480000  18.480000  7047900
# ...

# %%
PWR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1981 entries, 2010-01-04 to 2017-11-13
# Data columns (total 6 columns):
# Open         1981 non-null float64
# High         1981 non-null float64
# Low          1981 non-null float64
# Close        1981 non-null float64
# Adj Close    1981 non-null float64
# Volume       1981 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 108.3 KB

# %%
PWR.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2010-01-04  21.120001  21.280001  21.000000  21.240000  21.240000  2460200
# 2010-01-05  21.320000  21.500000  21.100000  21.330000  21.330000  2156000
# 2010-01-06  21.360001  22.100000  21.260000  21.940001  21.940001  2901900
# 2010-01-07  21.980000  22.350000  21.860001  22.270000  22.270000  1940800
# 2010-01-08  22.129999  22.219999  21.700001  21.860001  21.860001  2612400

# %%
PWR.tail()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2017-11-07  36.180000  36.270000  35.700001  36.209999  36.209999  1684000
# 2017-11-08  36.049999  36.599998  35.840000  36.340000  36.340000  1404400
# 2017-11-09  36.060001  36.189999  35.450001  35.509998  35.509998  1261700
# 2017-11-10  35.430000  35.980000  35.380001  35.840000  35.840000   850300
# 2017-11-13  35.660000  36.000000  35.660000  35.900002  35.900002   110637

# %%
power_stocks = ['PWR', 'ABB', 'XEL']
new_data = pd.DataFrame()
for t in power_stocks:
    new_data[t] = wb.DataReader(t, data_source='yahoo', start='2015-1-1')['Adj Close']

# %%
new_data.tail()
# Out:
#                   PWR        ABB        XEL
# Date
# 2017-11-07  36.209999  26.260000  50.029999
# 2017-11-08  36.340000  26.219999  50.250000
# 2017-11-09  35.509998  25.740000  50.509998
# 2017-11-10  35.840000  25.360001  50.200001
# 2017-11-13  35.830002  25.389999  50.360001

# %%
new_data.head()
# Out:
#                   PWR        ABB        XEL
# Date
# 2015-01-02  28.350000  18.885397  32.870087
# 2015-01-05  27.549999  18.258272  32.496986
# 2015-01-06  27.209999  18.007425  32.669891
# 2015-01-07  27.190001  17.962627  32.951996
# 2015-01-08  28.020000  18.195562  33.334209

# %%
import quandl

# %%
mydata_01 = quandl.get('FRED/GDP')

# %%
mydata_01.tail()
# Out:
#                 Value
# Date
# 2016-07-01  18729.130
# 2016-10-01  18905.545
# 2017-01-01  19057.705
# 2017-04-01  19250.009
# 2017-07-01  19495.476

# %%
mydata_01.head()
# Out:
#               Value
# Date
# 1947-01-01  243.080
# 1947-04-01  246.267
# 1947-07-01  250.115
# 1947-10-01  260.309
# 1948-01-01  266.173

# %%
import pandas as pd

# %%
mydata_01.to_csv('example_01.csv')

# %%
mydata_02 = pd.read_csv('Data_02.csv')

# %%
mydata_02.head()
# Out:
#          Date    Open      High     Low     Close      Volume  Ex-Dividend  \
# 0  2017-03-03  136.63  137.3300  136.08  137.1300  11095605.0          0.0
# 1  2017-03-02  137.09  137.8200  136.31  136.7603  12243028.0          0.0
# 2  2017-03-01  136.47  137.4800  136.30  137.4200  16257010.0          0.0
# 3  2017-02-28  136.79  136.8050  134.75  135.5400  16112092.0          0.0
# 4  2017-02-27  135.26  137.1846  135.02  136.4100  14306668.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 0          1.0     136.63   137.3300    136.08    137.1300   11095605.0
# 1          1.0     137.09   137.8200    136.31    136.7603   12243028.0
# 2          1.0     136.47   137.4800    136.30    137.4200   16257010.0
# 3          1.0     136.79   136.8050    134.75    135.5400   16112092.0
# 4          1.0     135.26   137.1846    135.02    136.4100   14306668.0

# %%
mydata_02.tail()
# Out:
#             Date   Open   High    Low    Close       Volume  Ex-Dividend  \
# 1200  2012-05-24  32.95  33.21  31.77  33.0300   50237200.0          0.0
# 1201  2012-05-23  31.37  32.50  31.36  32.0000   73600000.0          0.0
# 1202  2012-05-22  32.61  33.59  30.94  31.0000  101786600.0          0.0
# 1203  2012-05-21  36.53  36.66  33.00  34.0300  168192700.0          0.0
# 1204  2012-05-18  42.05  45.00  38.00  38.2318  573576400.0          0.0
#
#       Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 1200          1.0      32.95      33.21     31.77     33.0300   50237200.0
# 1201          1.0      31.37      32.50     31.36     32.0000   73600000.0
# 1202          1.0      32.61      33.59     30.94     31.0000  101786600.0
# 1203          1.0      36.53      36.66     33.00     34.0300  168192700.0
# 1204          1.0      42.05      45.00     38.00     38.2318  573576400.0

# %%
mydata_02.to_excel('example_02.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-50-be3eac2404c6> in <module>()
# ----> 1 mydata_02.to_excel('example_02.xlsx')
#
# /usr/lib64/python3.5/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1543         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1544                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1545                         engine=engine)
#    1546
#    1547     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# /usr/lib64/python3.5/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     641             need_save = False
# ...

# %%
mydata_03 = pd.read_excel('Data_03.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/lib64/python3.5/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     260         try:
# --> 261             import xlrd
#     262         except ImportError:
#
# ImportError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-52-08bf6e970f24> in <module>()
# ----> 1 mydata_03 = pd.read_excel('Data_03.xlsx')
#
# /usr/lib64/python3.5/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ...

# %%
mydata_03
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-4cc9d00e9462> in <module>()
# ----> 1 mydata_03
#
# NameError: name 'mydata_03' is not defined
